# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key
# Out:
# 'val'

# %%
# ensure annotations 

def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_prodict(x=2, y="3")
#
# File c:\Users\Dell\.conda\envs\kidney\Lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x000001A365861580> does not match annotation type <class 'int'>

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1o94yfB-vtXZ9ukOB3vWywlbPKe_6zaN-/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1o94yfB-vtXZ9ukOB3vWywlbPKe_6zaN-'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1o94yfB-vtXZ9ukOB3vWywlbPKe_6zaN-
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1o94yfB-vtXZ9ukOB3vWywlbPKe_6zaN-&confirm=t&uuid=057b79ea-5f14-4b8c-b083-7e0465373e82
# To: c:\Users\Dell\OneDrive\Desktop\MLops\Kidney-disease-classification-MLops\research\kidney.zip
# 100%|██████████| 1.64G/1.64G [04:26<00:00, 6.17MB/s]
# 'kidney.zip'
